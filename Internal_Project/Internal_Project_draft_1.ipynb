# %% [markdown]
# EV READING DATA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/celestinesheum/Desktop/MY-DAC-Curriculum/Internal_Project/Electric_Vehicles.csv')

# %%
df.head()
# Out:
#   User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0  User_1        BMW i3              108.463007         Station_391
# 1  User_2  Hyundai Kona              100.000000         Station_428
# 2  User_3    Chevy Bolt               75.000000         Station_181
# 3  User_4  Hyundai Kona               50.000000         Station_327
# 4  User_5  Hyundai Kona               50.000000         Station_108
#
#   Charging Station Location  Charging Start Time    Charging End Time  \
# 0                   Houston  2024-01-01 00:00:00  2024-01-01 00:39:00
# 1             San Francisco  2024-01-01 01:00:00  2024-01-01 03:01:00
# 2             San Francisco  2024-01-01 02:00:00  2024-01-01 04:48:00
# 3                   Houston  2024-01-01 03:00:00  2024-01-01 06:42:00
# 4               Los Angeles  2024-01-01 04:00:00  2024-01-01 05:46:00
#
#    Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# ...

# %%
df.tail()
# Out:
#         User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 1315  User_1316   Nissan Leaf              100.000000          Station_57
# 1316  User_1317        BMW i3              100.000000          Station_40
# 1317  User_1318   Nissan Leaf              100.000000         Station_374
# 1318  User_1319    Chevy Bolt               85.000000         Station_336
# 1319  User_1320   Nissan Leaf              120.447195         Station_128
#
#      Charging Station Location  Charging Start Time    Charging End Time  \
# 1315                  New York  2024-02-24 19:00:00  2024-02-24 20:30:00
# 1316                  New York  2024-02-24 20:00:00  2024-02-24 20:44:00
# 1317                  New York  2024-02-24 21:00:00  2024-02-24 23:03:00
# 1318             San Francisco  2024-02-24 22:00:00  2024-02-24 23:20:00
# 1319               Los Angeles  2024-02-24 23:00:00  2024-02-24 23:56:00
#
#       Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# ...

# %%
df.columns
# Out:
# Index(['User ID', 'Vehicle Model', 'Battery Capacity (kWh)',
#        'Charging Station ID', 'Charging Station Location',
#        'Charging Start Time', 'Charging End Time', 'Energy Consumed (kWh)',
#        'Charging Duration (hours)', 'Charging Rate (kW)',
#        'Charging Cost (USD)', 'Time of Day', 'Day of Week',
#        'State of Charge (Start %)', 'State of Charge (End %)',
#        'Distance Driven (since last charge) (km)', 'Temperature (°C)',
#        'Vehicle Age (years)', 'Charger Type', 'User Type'],
#       dtype='object')

# %%
df.shape
# Out:
# (1320, 20)

# %%
df.isnull().sum()
# Out:
# User ID                                      0
# Vehicle Model                                0
# Battery Capacity (kWh)                       0
# Charging Station ID                          0
# Charging Station Location                    0
# Charging Start Time                          0
# Charging End Time                            0
# Energy Consumed (kWh)                       66
# Charging Duration (hours)                    0
# Charging Rate (kW)                          66
# Charging Cost (USD)                          0
# Time of Day                                  0
# Day of Week                                  0
# State of Charge (Start %)                    0
# State of Charge (End %)                      0
# Distance Driven (since last charge) (km)    66
# Temperature (°C)                             0
# Vehicle Age (years)                          0
# Charger Type                                 0
# User Type                                    0
# dtype: int64

# %%
df.dropna()
# Out:
#         User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0        User_1        BMW i3              108.463007         Station_391
# 1        User_2  Hyundai Kona              100.000000         Station_428
# 2        User_3    Chevy Bolt               75.000000         Station_181
# 3        User_4  Hyundai Kona               50.000000         Station_327
# 4        User_5  Hyundai Kona               50.000000         Station_108
# ...         ...           ...                     ...                 ...
# 1315  User_1316   Nissan Leaf              100.000000          Station_57
# 1316  User_1317        BMW i3              100.000000          Station_40
# 1317  User_1318   Nissan Leaf              100.000000         Station_374
# 1318  User_1319    Chevy Bolt               85.000000         Station_336
# 1319  User_1320   Nissan Leaf              120.447195         Station_128
#
#      Charging Station Location  Charging Start Time    Charging End Time  \
# ...

# %%
vehicle_characteristics = df.groupby('Vehicle Age (years)').agg({ 
    'Battery Capacity (kWh)': 'mean', 
    'Distance Driven (since last charge) (km)': 'mean' 
}).reset_index() 
vehicle_characteristics.columns = ['Vehicle_Age_years', 'Avg_Battery_Capacity_kWh', 'Avg_Distance_Driven_km']

# %%
print(vehicle_characteristics)
# Out:
#      Vehicle_Age_years  Avg_Battery_Capacity_kWh  Avg_Distance_Driven_km
# 0             0.000000                 73.838652              159.398917
# 1             0.020156                 62.000000              250.864367
# 2             0.088598                 62.000000              269.148089
# 3             0.190047                 62.000000              129.545566
# 4             0.288408                 75.000000               67.717337
# ..                 ...                       ...                     ...
# 109           8.018666                 75.000000              279.519362
# 110           9.076121                 75.000000              190.237500
# 111          10.547237                 50.000000              242.453043
# 112          10.634574                100.000000              115.002815
# 113          11.688592                 75.000000              258.289678
#
# [114 rows x 3 columns]

# %%
import numpy as np

df['Charge Status'] = np.where(
    df['State of Charge (Start %)'] > df['State of Charge (End %)'],
    'NA',
    'Correct'
)

# %%
df[['State of Charge (Start %)', 'State of Charge (End %)', 'Charge Status']]
# Out:
#       State of Charge (Start %)  State of Charge (End %) Charge Status
# 0                     29.371576                86.119962       Correct
# 1                     10.115778                84.664344       Correct
# 2                      6.854604                69.917615       Correct
# 3                     83.120003                99.624328       Correct
# 4                     54.258950                63.743786       Correct
# ...                         ...                      ...           ...
# 1315                  39.204102                83.915952       Correct
# 1316                  31.456375                93.096461       Correct
# 1317                  71.903081                78.678879       Correct
# 1318                  76.187997                65.926573            NA
# 1319                  59.338076                56.692439            NA
#
# [1320 rows x 3 columns]

# %%
print(df['Charge Status'].unique())
# Out:
# ['NA' 'Correct']

# %%
df.dropna()
